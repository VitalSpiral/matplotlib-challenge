# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_cvs = "data/mouse_drug_data.csv"
clinical_trial_data_cvs = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
clinical_trial_data_df = pd.read_csv(clinical_trial_data_cvs)
mouse_drug_data_df = pd.read_csv(mouse_drug_data_cvs)

# Combine the data into a single dataset
drug_and_trial_df = pd.merge(clinical_trial_data_df, mouse_drug_data_df, on="Mouse ID")


# Display the data table for preview
drug_and_trial_df.head(10)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0           45.000000                 0  Capomulin
# 1     b128          5           45.651331                 0  Capomulin
# 2     b128         10           43.270852                 0  Capomulin
# 3     b128         15           43.784893                 0  Capomulin
# 4     b128         20           42.731552                 0  Capomulin
# 5     b128         25           43.262145                 1  Capomulin
# 6     b128         30           40.605335                 1  Capomulin
# 7     b128         35           37.967644                 1  Capomulin
# 8     b128         40           38.379726                 2  Capomulin
# 9     b128         45           38.982878                 2  Capomulin

# %%
tumor_volume_time_mouse_df=drug_and_trial_df.sort_values(["Timepoint", "Tumor Volume (mm3)"], ascending=True)

new_tumor_volume_time_mouse_df=tumor_volume_time_mouse_df.reset_index(drop=True)

new_tumor_volume_time_mouse_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0                45.0                 0  Capomulin
# 1     f932          0                45.0                 0   Ketapril
# 2     g107          0                45.0                 0   Ketapril
# 3     a457          0                45.0                 0   Ketapril
# 4     c819          0                45.0                 0   Ketapril

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint
tumor_volumes=new_tumor_volume_time_mouse_df.sort_values(["Drug", "Timepoint"], ascending=True)

tumor_volumes_group=tumor_volumes.groupby(["Drug", "Timepoint"])

tumor_volumes_group_comparison=tumor_volumes_group.mean()

tumor_volumes_group_comparison_df=pd.DataFrame(tumor_volumes_group_comparison).reset_index()

tumor_volumes_group_comparison_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0  Capomulin          0           45.000000          0.000000
# 1  Capomulin          5           44.266086          0.160000
# 2  Capomulin         10           43.084291          0.320000
# 3  Capomulin         15           42.064317          0.375000
# 4  Capomulin         20           40.716325          0.652174

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
tumor_volumes_group_sem=tumor_volumes_group.sem()

tumor_volumes_group_sem.head()

# Convert to DataFrame

tumor_volumes_group_sem_df=pd.DataFrame(tumor_volumes_group_sem).reset_index()

# Preview DataFrame

tumor_volumes_group_sem_df.head()
# Out:
#         Drug  Timepoint  Metastatic Sites  Mouse ID  Tumor Volume (mm3)
# 0  Capomulin          0          0.000000       NaN            0.000000
# 1  Capomulin          5          0.074833       NaN            0.448593
# 2  Capomulin         10          0.125433       NaN            0.702684
# 3  Capomulin         15          0.132048       NaN            0.838617
# 4  Capomulin         20          0.161621       NaN            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames

pd.pivot_table(tumor_volumes_group_comparison_df, values = "Tumor Volume (mm3)", index = ['Timepoint'], columns = "Drug")

# Preview that Reformatting worked
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)
x_axis_data=np.arange(0,50,5)
x_axis_data

tumor_volumes_group_comparison_df.plot(x = "Timepoint", y="Tumor Volume (mm3)")

# Save the Figure

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
tumor_metastatic=new_tumor_volume_time_mouse_df.sort_values(["Drug", "Timepoint"], ascending=True)

tumor_volumes_group=tumor_volumes.groupby(["Drug", "Timepoint"])

tumor_volumes_group_comparison=tumor_volumes_group.mean()

tumor_volumes_group_comparison_df=pd.DataFrame(tumor_volumes_group_comparison).reset_index()

tumor_volumes_group_comparison_df.head()

# Convert to DataFrame

# Preview DataFrame

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
